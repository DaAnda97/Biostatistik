# %% [markdown]
# # Skelletanomalien bei Geburten

# %%
x_star = c(0,3,0)
p_null = c(0.7,0.2,0.1)

# %% [markdown]
# ## Multinomialtest - per Hand

# %%
p_stern = dmultinom(x_star, 3, p_null)
p_stern
# Out:
# [1] 0.008

# %%
# TBD

# %% [markdown]
# ## Mit Multinomialtest vorimplementiert

# %%
install.packages('EMT')
library(EMT)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
out = multinomial.test(observed = x_star, prob = p_null)
plotMultinom(out)
# Out:
#  Exact Multinomial Test, distance measure: p
#
#     Events    pObs    p.value
#         10   0.008      0.015
# Plot with title “Exact Multinomial Test”
